# %%
#list length-data types
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
for fields in range(1,6):
  print(f"irrigation field {fields}")
# Out:
# irrigation field 1
# irrigation field 2
# irrigation field 3
# irrigation field 4
# irrigation field 5

# %%
while True:
  pest_count=int(input("enter pest count:"))
  if pest_count==0:
    print("monitoring stopped")
    break
  else:
    print(f"pest count recorded:{pest_count}")
# Out:
# enter pest count:6
# pest count recorded:6
# enter pest count:8
# pest count recorded:8
# enter pest count:0
# monitoring stopped
