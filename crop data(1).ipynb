# %%
crop_name="groundnut"
print(crop_name[0])
print(crop_name[-1])
print(crop_name[:5])
print(crop_name[5:])
# Out:
# g
# t
# groun
# dnut

# %%
crop="rice"
soil_type="black soil"
print(crop)
print(soil_type)
# Out:
# rice
# black soil

# %%
print("rice".upper())
print("WHEAT".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
row_crop="rice"
print(row_crop.strip())
print("wheat".lstrip("*"))
print("maize###".rstrip("#"))
# Out:
# rice
# wheat
# maize

# %%
text="organic rice and rice cultivation"
print(text.find("rice"))
print(text.count("rice"))
print("rice"in text)
# Out:
# 8
# 2
# True

# %%
print("rice".isalpha())
print("2026".isdigit())
print("plot 12".isalnum())
print("".isspace())
# Out:
# True
# True
# False
# False

# %%
codes=[
    "CRP_RICE_2026",
    "CRP_WHEAT_2025",
    "CRP_MANGO_2026",
    "CRP_MAIZE_2024"
]
clean_codes=[]
for code in codes:
 if code.startswith("CRP_"):
  clean_codes.append(code[4:])
  print(clean_codes)
# Out:
# ['RICE_2026']
# ['RICE_2026', 'WHEAT_2025']
# ['RICE_2026', 'WHEAT_2025', 'MANGO_2026']
# ['RICE_2026', 'WHEAT_2025', 'MANGO_2026', 'MAIZE_2024']

# %%
clean_codes=[print(code[4:]) for code in codes if code.startswith("CRP_")]
# Out:
# RICE_2026
# WHEAT_2025
# MANGO_2026
# MAIZE_2024

# %%
for crop_code in codes:
  if crop_code.startswith("CRP_"):
    code,crop,year=crop_code.split("_")
    print(crop,year)
# Out:
# RICE 2026
# WHEAT 2025
# MANGO 2026
# MAIZE 2024

# %%
raw_record="Rice,1200,black soil**"
clean_record=raw_record.rstrip("*") # Remove trailing asterisks
crop,yield_kg,soil=clean_record.split(",") # Split the cleaned string
crop=crop.title()
print(f"crop:{crop}")
print(f"yield_kg:{yield_kg}")
print(f"soil:{soil}") # Corrected f-string
# Out:
# crop:Rice
# yield_kg:1200
# soil:black soil

# %%
raw_record="Rice,1200,black soil**"
clean_record=raw_record.rstrip("*")
crop,yield_kg,soil=clean_record.split(",")
crop=crop.title()
print(f"crop:{crop}")
print(f"yield_kg:{yield_kg}")
print(f"soil:{soil}")
# Out:
# crop:Rice
# yield_kg:1200
# soil:black soil

# %%
for crop_code in codes:
  if crop_codes.startswith("CRP_"):
