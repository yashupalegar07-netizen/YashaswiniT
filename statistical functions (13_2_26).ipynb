# %%
import numpy as np
n=int(input("enter number of months:"))
print("\n enter rainfall data(mm):")

rainfall_list=[]
print("\n enter crop yield data(tons/ha):")
yield_list=[]
rainfall=np.array(rainfall_list)
yields=np.array(yield_list)
# Out:
# enter number of months:12
#
#  enter rainfall data(mm):
#
#  enter crop yield data(tons/ha):

# %%
import numpy as np
n=int(input("enter the number of months"))
for i in range(n):
  data=float(input("enter rainfall(mm):"))
  rainfall_data=[]
  rainfall_data.append(data)
  rainfall=np.array([rainfall_data])
# Out:
# enter the number of months12
# enter rainfall(mm):300
# enter rainfall(mm):500
# enter rainfall(mm):60
# enter rainfall(mm):700
# enter rainfall(mm):400
# enter rainfall(mm):150
# enter rainfall(mm):450
# enter rainfall(mm):800
# enter rainfall(mm):860
# enter rainfall(mm):630
# enter rainfall(mm):660
# enter rainfall(mm):770

# %%
import numpy as np
n=int(input("enter the number of months"))
for i in range(n):
  data=float(input("enter rainfall(mm):"))
  rainfall_data=[]
  rainfall_data.append(data)
  rainfall=np.array([rainfall_data])
for i in range(n):
  yield_data=float(input("enter yield(tons/ha):"))
  yields=[]
  yields.append(yield_data)
  yields_data=np.array([yield_data])
# Out:
# enter the number of months6
# enter rainfall(mm):300
# enter rainfall(mm):500
# enter rainfall(mm):700
# enter rainfall(mm):450
# enter rainfall(mm):770
# enter rainfall(mm):650
# enter yield(tons/ha):25
# enter yield(tons/ha):50
# enter yield(tons/ha):45
# enter yield(tons/ha):52
# enter yield(tons/ha):28
# enter yield(tons/ha):34

# %%
import numpy as np
n=int(input("enter the number of months"))
for i in range(n):
  data=float(input("enter rainfall(mm):"))
  rainfall_data=[]
  rainfall_data.append(data)
  rainfall=np.array([rainfall_data])
for i in range(n):
  yield_data=float(input("enter yield(tons/ha):"))
  yields=[]
  yields.append(yield_data)
  yields_data=np.array([yield_data])
  print('===RAINFALL STATISTICS===')
print(f'mean:{np.mean(rainfall):2f}mm')
print(f'median:{np.median(rainfall):2f}mm')
print(f'std dev:{np.std(rainfall):2f}mm')
print(f'variance:{np.var(rainfall):2f}mm')
print(f'min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'max:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
print(f'range:{np.ptp(rainfall)}mm')
print("\n===YIELD STATISTICS===")
print(f'mean:{np.mean(yields):2f}tons/ha')
print(f'median:{np.median(yields):2f}tons/ha')
print(f'std dev:{np.std(yields):2f}tons/ha')
print('\n===PERCENTILES===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:2f}mm')
print('\n===CORRELATION ANALYSIS===')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'rainfall-yield correlation:{correlation:4f}')
print('interpretation:strong positive correlation' if correlation>0.7 else 'moderate correlation' if correlation>0.4 else 'weak correlation')
print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('month\trainfall\tcumulative')
for month,(rain,cum)in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# enter the number of months2
# enter rainfall(mm):45
# enter rainfall(mm):105
# enter yield(tons/ha):4
# ===RAINFALL STATISTICS===
# enter yield(tons/ha):34
# ===RAINFALL STATISTICS===
# mean:105.000000mm
# median:105.000000mm
# std dev:0.000000mm
# variance:0.000000mm
# min:105.0mm(month1)
# max:105.0mm(month1)
# range:0.0mm
#
# ===YIELD STATISTICS===
# mean:34.000000tons/ha
# median:34.000000tons/ha
# std dev:0.000000tons/ha
#
# ===PERCENTILES===
# 25th percentile rainfall:105.000000mm
# 50th percentile rainfall:105.000000mm
# 75th percentile rainfall:105.000000mm
# 90th percentile rainfall:105.000000mm
#
# ===CORRELATION ANALYSIS===
# rainfall-yield correlation: nan
# weak correlation
#
# ===CUMULATIVE RAINFALL===
# month	rainfall	cumulative
# 1	[105.]		105.0
