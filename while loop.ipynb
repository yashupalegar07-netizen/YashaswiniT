# %%
print(3&5)
# Out:
# 1

# %%
i=1
while i<=5:
  i+=2
  print(i)
# Out:
# 3
# 5
# 7

# %%
total=0
nums = [3,6,9,12]
for n in nums:
  total+=n

# %%
nums=[1,2,3,4,5]
for i in range(len(nums)):
  if nums[i]>3:
    print(nums[i])
  i+=1
# Out:
# 4
# 5

# %%
nums=[1,2,3,4,5]
for n in nums:
  if n>3:
    print(n)
# Out:
# 4
# 5

# %%
x=10
y=x
x=5
print(y)
# Out:
# 10

# %%
nums=[1,2,3,4]
for n in nums:
  print(n)
# Out:
# 1
# 2
# 3
# 4

# %%
nums=[1,2,3,4]
for i in range(len(nums)):
  nums[i]*=2
print(nums)
# Out:
# [2, 4, 6, 8]

# %%
print(5^3)
# Out:
# 6

# %%
nums=[1,2,3,4,5]
i=0
while i<len(nums):
  if nums[i]%2==0:
    nums.pop(i)
  else:
    i+=1
print(nums)
# Out:
# [1, 3, 5]

# %%
nums=[10,20,30]
i=0
while i<len(nums):
  print(nums[i])
  i+=1
# Out:
# 10
# 20
# 30

# %%
nums=[5,10,15]
for n in nums:
  n+=5
print(n)
# Out:
# 20

# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
  squares.append(n**2)
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
x=25
if x>10:
  if x>20:
    print("A")
  else:
    print("B")
else:
  print("C")
# Out:
# A

# %%
lst=[1,2,3,4]
for x in lst:
  if x % 2==0:
    lst.remove(x)
print(lst)
# Out:
# [1, 3]

# %%
i=0
while i<5:
  i+=1
  if i==3:
    continue
  print(i,end="")
# Out:
# 1245

# %%
lst=[1,2,3]
for x in lst:
  lst.append(x)
  if len(lst)>4:
    break
  print(lst)
# Out:
# [1, 2, 3, 1]

# %%
x=15
if x>10:
  print("A")
if x>5:
  print("B")
# Out:
# A
# B

# %%
for i in range(1,6):
  if i%2==0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
