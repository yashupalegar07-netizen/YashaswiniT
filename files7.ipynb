# %%
def number_of_crops():
  return 150
number_of_crops()
# Out:
# 150

# %%
def weather_update():
  print("the weather today is sunny with no rain expected")
weather_update()
# Out:
# the weather today is sunny with no rain expected

# %%
def plant_info(plant_name):
  print(f"the {plant_name},requires atleast 8 hours of sunlight per day")
plant_info("mango tree")
# Out:
# the mango tree,requires atleast 8 hours of sunlight per day

# %%
def water_needs(plant_type):
  if plant_type=="corn":
   return 30
  elif plant_type=="wheat":
   return 20
  else:
   return 25
water_needs("corn")
# Out:
# 30

# %%
def irrigation_needed(moisture_level,rainfall):
  if moisture_level<40 and rainfall<10:
    print("irrigation needed")
  else:
    print("irrigation not needed")
irrigation_needed(40,10)
# Out:
# irrigation not needed

# %%
def total_yield(area,yield_per_hectare):
  return area*yield_per_hectare
total_yield(2,20)
# Out:
# 40

# %%
def total_yield():
 area=int(input("enter the area"))
 yield_per_hectare=float(input("enter the yield per hectare"))
 calculated_yield=area*yield_per_hectare
 return calculated_yield
y=total_yield()
print(y)
# Out:
# enter the area20
# enter the yield per hectare70
# 1400.0

# %%
def is_ready_for_harvest(days_since_planted,plant_type):
  if days_since_planted>=20 and plant_type=="rice":
   return True
  else:
    return False
plant_type=input("enter the plant type")
days_since_planted=int(input("enter the number of days since planted"))
is_ready_for_harvest(days_since_planted,plant_type)
# Out:
# enter the plant typerice
# enter the number of days since planted19
# False

# %%
def weather_condition():
  temperature=28
  humidity=70
  return temperature,humidity
temp,hum = weather_condition()
print(f"temperature:{temp}C,humidity:{hum}%")
# Out:
# temperature:28C,humidity:70%

# %%
def add(x,y):
  return x+y
def subtract(x,y):
  return x-y
def multiply(x,y):
  return x*y
def divide(x,y):
  if y==0:
    return"error!division by zero"
  else:
    return x/y
def get_input():
  try:
    x=float(input("enter the first number:"))
    y=float(input("enter the second number:"))
    return x,y
  except ValueError:
    print("invalid input!please enter valid numbers")
    return get_input()
def print_menu():
 print("\nselect operation:")
 print("1.add")
 print("2.subtract")
 print("3.multiply")
 print("4.divide")
 print("5.exit")
def calculator():
  while True:
    print_menu()
    choice=input("enter choice(1/2/3/4/5):")
    if choice=="5":
      print("exiting calculator")
      break
    x,y=get_input()
    if choice=="1":
      print(f"{x}+{y}={add(x,y)}")
    elif choice=="2":
      print(f"{x}-{y}={subtract(x,y)}")
    elif choice=="3":
      print(f"{x}*{y}={multiply(x,y)}")
    elif choice=="4":
      print(f"{x}/{y}={divide(x,y)}")
    else:
      print("invalid input!please select a valid operation(1\\2\\3\\4\\5)")
calculator()
print("done with the progam")
# Out:
# select operation:
# 1.add
# 2.subtract
# 3.multiply
# 4.divide
# 5.exit
