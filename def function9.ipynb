# %%
farm_data=[
    [1,"rice",45],
    [2,"wheat",30],
    [3,"maize",60]
]
print(farm_data)
print(farm_data[0])
print(farm_data[0][1])
# Out:
# [[1, 'rice', 45], [2, 'wheat', 30], [3, 'maize', 60]]
# [1, 'rice', 45]
# rice

# %%
yield_data=[
    ["rice",3200],
    ["wheat",2800],
    ["maize",4000]
]
for crop in yield_data:
  print(crop[0],"yield:",crop[1],"kg/hectare")
# Out:
# rice yield: 3200 kg/hectare
# wheat yield: 2800 kg/hectare
# maize yield: 4000 kg/hectare

# %%
crop_plan=[
    ["kharif",["rice","maize"]],
    ["rabi",["wheat","gram"]],
    ["zaid",["vegetables"]]
]
print(crop_plan[0])
print(crop_plan[2])
print(crop_plan[2][0])
# Out:
# ['kharif', ['rice', 'maize']]
# ['zaid', ['vegetables']]
# zaid

# %%
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
]
print(expenses[0])
for day in expenses:
  print(day[0],"total:",sum(day[1]))
# Out:
# ['day1', [1200, 500, 300]]
# day1 total: 2000
# day2 total: 2500
# day3 total: 1900

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses
total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
# Out:
# enter the number of days3
# enter the day namesunday
# enter the seed cost:2000
# enter the fertilizer cost:1200
# enter the labour cost:1500
# enter the day namemonday
# enter the seed cost:1500
# enter the fertilizer cost:1200
# enter the labour cost:1500
# enter the day namethursday
# enter the seed cost:1000
# enter the fertilizer cost:1200
# enter the labour cost:1500
# daily expenses
# sunday expenses are [2000, 1200, 1500]
# monday expenses are [1500, 1200, 1500]
# thursday expenses are [1000, 1200, 1500]

# %%
thistuple=("apple","banana","cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple=("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
thistuple=("apple")
print(type(thistuple))
# Out:
# <class 'str'>
