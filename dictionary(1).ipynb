# %%
thisdict={
    "crop":"rice",
    "variety":"ir 64",
    "year":2024
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'ir 64', 'year': 2024}

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2023,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'year': 2023, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={
    "crop":"rice",
    "variety":"ir 64",
    "year":2024
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
thisdict=dict(
    farmer_name="ramesh",
    age=45,
    village="tumkur"
)
print(thisdict)
# Out:
# {'farmer_name': 'ramesh', 'age': 45, 'village': 'tumkur'}

# %%
thisdict={
    "crop":"rice",
    "variety":"ir 64",
    "year":2024
}
x=thisdict["variety"]
print(x)
# Out:
# ir 64

# %%
thisdict={
    "crop":"rice",
    "variety":"ir 64",
    "year":2024
}
x=thisdict.get("variety")
print(x)
# Out:
# ir 64

# %%
thisdict={
    "crop":"rice",
    "variety":"ir 64",
    "year":2024
}
x=thisdict.keys()
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])

# %%
farm={
    "crop":"rice",
    "variety":"ir-64",
    "year":2022
}
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])

# %%
farm={
    "crop":"rice",
    "variety":"ir-64",
    "year":2022
}
x=thisdict.values()
print(x)
farm["yield"]=2024
print(x)
# Out:
# dict_values(['rice', 'ir 64', 2024])
# dict_values(['rice', 'ir 64', 2024])

# %%
farm={
    "crop":"rice",
    "variety":"ir-64",
    "year":2024
}
x=thisdict.values()
print(x)
# Out:
# dict_values(['rice', 'ir 64', 2024])

# %%
farm={
    "crop":"rice",
    "variety":"ir-64",
    "year":2024
}
x=farm.values()
print(x)
farm["year"]=2024
print(x)
# Out:
# dict_values(['rice', 'ir-64', 2024])
# dict_values(['rice', 'ir-64', 2024])

# %%
farm={
    "crop":"rice",
    "variety":"ir-64",
    "year":2024
}
x=thisdict.items()
print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=tuple(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))
# Out:
# dict_items([('crop', 'rice'), ('variety', 'ir 64'), ('year', 2024)])
# (('crop', 'rice'), ('variety', 'ir 64'), ('year', 2024))
# dict_items([('crop', 'rice'), ('variety', 'ir 64'), ('year', 2024)])
# ('crop', 'variety', 'year')
# ('rice', 'ir 64', 2024)
# (('crop', 'rice'), ('variety', 'ir 64'), ('year', 2024))

# %%
thisdict={
    "crop":"rice",
    "variety":"ir-64",
    "year":2022
}
if "variety" in thisdict:
  print("yes,'variety' is one of the keys in the thisdict dictionary")
# Out:
# yes,'variety' is one of the keys in the thisdict dictionary

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
    "marks":98
}
print("original dictionary:",student)
# Out:
# original dictionary: {'name': 'monika', 'roll_no': 2140, 'branch': 'cse', 'marks': 98}

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
    "marks":98
}
student_copy=student.copy()
print("copied dictionary:",student_copy)
# Out:
# copied dictionary: {'name': 'monika', 'roll_no': 2140, 'branch': 'cse', 'marks': 98}

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
    "marks":98
}
removed_value=student.pop("marks")
print("removed value:",removed_value)
print("after pop():",student)
# Out:
# removed value: 98
# after pop(): {'name': 'monika', 'roll_no': 2140, 'branch': 'cse'}

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
    "marks":98
}
last_item=student.popitem()
print("removed item:",last_item)
print("after update():",student)
# Out:
# removed item: ('marks', 98)
# after update(): {'name': 'monika', 'roll_no': 2140, 'branch': 'cse'}

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
    "marks":98
}
student.clear()
print("after clear():",student)
# Out:
# after clear(): {}

# %%
student={
    "name":"monika",
    "roll_no":2140,
    "branch":"cse",
}
del student
